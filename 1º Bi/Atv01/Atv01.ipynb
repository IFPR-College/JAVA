// %% [markdown]
// # Atv01

// %% [markdown]
// Apresente a soma de todos os argumentos inteiros ou reais recebidos

// %%
        Scanner scanner = new Scanner(System.in);

        System.out.print("Informe um inteiro: ");
        int value = scanner.nextInt();
        System.out.println("o inteiro informado é: " + value);

        sumVar();
        payment();

    

        System.out.println("///////////////////////////////////");
        int b = 8;
        int c = 4;
        int a = b * c;

        System.out.println("A soma das duas variáveis é: " + a);
    

        System.out.println("///////////////////////////////////");
        int desconto = 200;
        int inss = 100;
        int salario = 1900;
        int resto = salario - (desconto + inss);
        System.out.println("O salario final ficou: " + resto); // essa é um calculo de exemplo de folha de pagamento
// Out:
// Digite um número ou 's' para sair: 50
// Digite um número ou 's' para sair: 62.5
// Digite um número ou 's' para sair: 15.5
// Digite um número ou 's' para sair: s
// A soma total é: 128.0
// null
